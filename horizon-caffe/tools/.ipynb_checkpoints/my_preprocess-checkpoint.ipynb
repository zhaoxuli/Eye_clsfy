# %% [markdown]
# # 1. List train folders

# %% [markdown]
# ## 1.1. Generate "train_folders.txt"

# %%
# %%bash
# python list_train_folders.py -root_dir=/home/users/dawei.yang/data/data_1106/ -dir_type="a_open|glass_open|a_close|glass_close" > /home/users/dawei.yang/zhaoxu.li/mxnet_eye/eycls_scrip/data/1109_data/train_folders.txt

# %% [markdown]
# # 3. Disturb pictures

# %% [markdown]
# ## 3.1.Count number of all classes

# %%
import os
import glob
import argparse

#src_folders = '/home/users/dawei.yang/feng.han/ec_0926/file_list/train_folders.txt'
src_folders = '/home/users/dawei.yang/zhaoxu.li/mxnet_eye/eycls_scrip/data/1109_data/train_folders.txt'


def skip_comments_and_blank(file, cm='#'):
    lines = list()
    for line in file:
        line = line.strip()
        if not line.startswith(cm) and not line.isspace():
            lines.append(line)
    return lines


if __name__ == '__main__':
    dir_types = {}
    lines = skip_comments_and_blank(open(src_folders))
    for sub_dir in lines:
        dir_type = sub_dir.split(os.sep)[-1]
        if dir_type not in dir_types:
            print 'add', dir_type, 'in dir_types'
            dir_types[dir_type] = 0
       
        # count the number of files
        num = len(glob.glob(sub_dir+'/*'))
        dir_types[dir_type] += num
        print sub_dir, num
            
    print 'sum up:', dir_types
# Out:
# add a_close in dir_types
# /home/users/dawei.yang/data/data_1106/Anno0914/10184/a_close 0
# add glass_open in dir_types
# /home/users/dawei.yang/data/data_1106/Anno0914/10184/glass_open 134
# add glass_close in dir_types
# /home/users/dawei.yang/data/data_1106/Anno0914/10184/glass_close 208
# add a_open in dir_types
# /home/users/dawei.yang/data/data_1106/Anno0914/10184/a_open 0
# /home/users/dawei.yang/data/data_1106/Anno0914/10176/a_close 16
# /home/users/dawei.yang/data/data_1106/Anno0914/10176/glass_open 898
# /home/users/dawei.yang/data/data_1106/Anno0914/10176/glass_close 738
# /home/users/dawei.yang/data/data_1106/Anno0914/10176/a_open 4
# /home/users/dawei.yang/data/data_1106/Anno0914/10281/a_close 77
# /home/users/dawei.yang/data/data_1106/Anno0914/10281/glass_open 1228
# /home/users/dawei.yang/data/data_1106/Anno0914/10281/glass_close 170
# /home/users/dawei.yang/data/data_1106/Anno0914/10281/a_open 206
# /home/users/dawei.yang/data/data_1106/Anno0914/10288/a_close 145
# ...

# %% [markdown]
# ## 3.2. Generate disturb commands in disturb_pic.sh

# %%
import os

PRE_PRINT_RES = True

#save_path
save_path = '/home/users/dawei.yang/data/20171109_train_test'
# 需要处理的文件夹列表
#src_folders = '/home/users/dawei.yang/feng.han/ec_0926/file_list/train_folders.txt'
src_folders = '/home/users/dawei.yang/zhaoxu.li/mxnet_eye/eycls_scrip/data/1109_data/train_folders.txt'

# 存储的脚本名称
fn_cmd = "disturb_in_pic.sh"

# 扰动脚本
disturb_script = 'disturb_in_eye_pic.py'
#disturb_script = 'disturb_in_eye_pic_gray.py'
# 扰动倍数
#disturb_times = {'a_close':5, 'a_open':2, 'glass_close':13, 'glass_open':2,}
#disturb_times = {'a_close':5, 'a_open':2, 'glass_close':12, 'glass_open':2,}
disturb_times = {'a_open':1, 'glass_open':1, 'glass_close':5, 'a_close':2,}
#disturb_times = {'a_close':1, 'a_open':1, 'glass_close':8, 'glass_open':3,}

def skip_comments_and_blank(file, cm='#'):
    lines = list()
    for line in file:
        #print line
        line = line.strip()
        if not line.startswith(cm) and not line.isspace():
            lines.append(line)
    return lines


if __name__ == '__main__':
        
    out_f = open(fn_cmd, 'w')
    
    lines = skip_comments_and_blank(open(src_folders))
    for line in lines:
        if line[-1] == os.sep:
            line = line[:-1]
            
        class_dir = line.split(os.sep)[-1] # a_close
        disturb_time = disturb_times[class_dir]
        out_line = 'python ' + disturb_script
        out_line += ' -pic_dir=' + line + ' -save_path=' + save_path + ' -disturb_time=' + str(disturb_time)
            
        if PRE_PRINT_RES:
            print out_line
        out_f.write(out_line + '\n')
        
    out_f.truncate(out_f.tell()-1)
    out_f.close()
# Out:
# python disturb_in_eye_pic.py -pic_dir=/home/users/dawei.yang/data/data_1106/Anno0914/10184/a_close -save_path=/home/users/dawei.yang/data/20171109_train_test -disturb_time=2
# python disturb_in_eye_pic.py -pic_dir=/home/users/dawei.yang/data/data_1106/Anno0914/10184/glass_open -save_path=/home/users/dawei.yang/data/20171109_train_test -disturb_time=1
# python disturb_in_eye_pic.py -pic_dir=/home/users/dawei.yang/data/data_1106/Anno0914/10184/glass_close -save_path=/home/users/dawei.yang/data/20171109_train_test -disturb_time=5
# python disturb_in_eye_pic.py -pic_dir=/home/users/dawei.yang/data/data_1106/Anno0914/10184/a_open -save_path=/home/users/dawei.yang/data/20171109_train_test -disturb_time=1
# python disturb_in_eye_pic.py -pic_dir=/home/users/dawei.yang/data/data_1106/Anno0914/10176/a_close -save_path=/home/users/dawei.yang/data/20171109_train_test -disturb_time=2
# ...

# %% [markdown]
# ## 3.3. Do disturb
#
# `sh disturb_pic.sh`只能单线程运行，可以执行`python disturb_on_multi_cpus.py`，但是最好在terminal执行！！！

# %%
# !sh disturb_in_pic.sh

# %% [markdown]
# # 2. list train files
# ```
# !python list_train_files.py /home/austin/Data/DMS_Eyes0710/20170512_JOC/20170511-78p/r0009/a_close  > train_files.txt
# ```

# %%
# !python list_train_files.py /home/users/dawei.yang/data/20171109_train_test/train -recursive=1 > /home/users/dawei.yang/zhaoxu.li/mxnet_eye/eycls_scrip/data/1109_data/train_files.txt
# !python list_train_files.py /home/users/dawei.yang/data/20171109_train_test/test -recursive=1 > /home/users/dawei.yang/zhaoxu.li/mxnet_eye/eycls_scrip/data/1109_data/test_files.txt

# %% [markdown]
# ## 4.2 Convert to mxnet lst

# %%
# !python convert_caffeList_to_mxnetList.py ../mxnet_eye/data/train_files.txt ../mxnet_eye/data/ eye_train.lst
# !python convert_caffeList_to_mxnetList.py ../mxnet_eye/data/train_files.txt ../mxnet_eye/data/eye_train.lst

# %%
python im2rec.py --color=0 --encoding='.png' --num-thread=4 --reszie=32 ../data/1023_data/ ../data/1023_data/
